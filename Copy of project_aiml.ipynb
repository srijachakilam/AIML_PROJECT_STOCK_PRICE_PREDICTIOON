# %%
import pandas as pd

# %%
d=pd.read_csv('/content/drive/MyDrive/AIML/ADANIPORTS CSV FILE ')

# %%
print(d)
# Out:
#             Date      Symbol Series  Prev Close   Open    High     Low   Last  \
# 0     17-01-2012  ADANIPORTS     EQ      135.50  137.1  141.00  135.00  140.1
# 1     18-01-2012  ADANIPORTS     EQ      140.00  142.0  143.80  138.70  143.0
# 2     19-01-2012  ADANIPORTS     EQ      141.70  144.0  150.55  143.15  149.5
# 3     20-01-2012  ADANIPORTS     EQ      149.40  151.9  157.60  150.25  155.4
# 4     23-01-2012  ADANIPORTS     EQ      155.40  155.4  155.40  145.10  146.4
# ...          ...         ...    ...         ...    ...     ...     ...    ...
# 2294  26-04-2021  ADANIPORTS     EQ      725.35  733.0  739.65  728.90  729.2
# 2295  27-04-2021  ADANIPORTS     EQ      730.75  735.0  757.50  727.35  748.6
# 2296  28-04-2021  ADANIPORTS     EQ      749.15  755.0  760.00  741.10  743.4
# 2297  29-04-2021  ADANIPORTS     EQ      746.25  753.2  765.85  743.40  746.4
# 2298  30-04-2021  ADANIPORTS     EQ      746.75  739.0  759.45  724.50  726.4
#
# ...

# %%
from matplotlib import pyplot as pt

# %%
x=d['Close']
y=d['Open']
pt.plot(x,y)

# %%
x=d['High']
y=d['Low']
pt.plot(x,y)

# %%
x=d['Prev Close']
y=d['Open']
pt.plot(x,y)

# %%
x=d['High']
y=d['Low']
pt.plot(x,y)

# %%
x=d['Last']
y=d['Close']
pt.plot(x,y)

# %%
x=d['VWAP']
y=d['Volume']
pt.plot(x,y)

# %%
x=d['Prev Close']
y=d['Deliverable Volume']
pt.plot(x,y)

# %%
x=d['Open']
y=d['Deliverable Volume']
pt.plot(x,y)

# %%
  x=d['High']
  y=d['Deliverable Volume']
pt.plot(x,y)

# %%
x=d['Low']
y=d['Deliverable Volume']
pt.plot(x,y)

# %%
x=d['Last']
y=d['Deliverable Volume']
pt.plot(x,y)

# %%
x=d['Close']
y=d['Deliverable Volume']
pt.plot(x,y)

# %%
x=d['VWAP']
y=d['Deliverable Volume']
pt.plot(x,y)

# %%
x=d['Volume']
y=d['Deliverable Volume']
pt.plot(x,y)

# %%
x=d['Turnover']
y=d['Deliverable Volume']
pt.plot(x,y)

# %%
x=d['Trades']
y=d['Deliverable Volume']
pt.plot(x,y)

# %%
x=d['%Deliverble']
y=d['Deliverable Volume']
pt.plot(x,y)

# %%
x=d['Prev Close']
y=d['Open']
pt.plot(x,y)

# %%
x=d['Prev Close']
y=d['High']
pt.plot(x,y)

# %%
x=d['Prev Close']
y=d['Low']
pt.plot(x,y)

# %%
x=d['Prev Close']
y=d['Last']
pt.plot(x,y)

# %%
x=d['Prev Close']
y=d['Close']
pt.plot(x,y)

# %%
x=d['Prev Close']
y=d['VWAP']
pt.plot(x,y)

# %%
x=d['Prev Close']
y=d['Volume']
pt.plot(x,y)

# %%
x=d['Prev Close']
y=d['Turnover']
pt.plot(x,y)

# %%
x=d['Prev Close']
y=d['Trades']
pt.plot(x,y)

# %%
x=d['Prev Close']
y=d['%Deliverble']
pt.plot(x,y)

# %%
x=d['Open']
y=d['High']
pt.plot(x,y)

# %%
x=d['Open']
y=d['Low']
pt.plot(x,y)

# %%
x=d['Open']
y=d['Last']
pt.plot(x,y)

# %%
x=d['Open']
y=d['Close']
pt.plot(x,y)

# %%
x=d['Open']
y=d['VWAP']
pt.plot(x,y)

# %%
x=d['Open']
y=d['Volume']
pt.plot(x,y)

# %%
x=d['Open']
y=d['Turnover']
pt.plot(x,y)

# %%
x=d['Open']
y=d['Trades']
pt.plot(x,y)

# %%
x=d['Open']
y=d['%Deliverble']
pt.plot(x,y)

# %%
x=d['High']
y=d['Low']
pt.plot(x,y)

# %%
x=d['High']
y=d['Last']
pt.plot(x,y)

# %%
x=d['High']
y=d['Close']
pt.plot(x,y)

# %%
x=d['High']
y=d['VWAP']
pt.plot(x,y)

# %%
x=d['High']
y=d['Volume']
pt.plot(x,y)

# %%
x=d['High']
y=d['Turnover']
pt.plot(x,y)

# %%
x=d['High']
y=d['Trades']
pt.plot(x,y)

# %%
x=d['High']
y=d['%Deliverble']
pt.plot(x,y)

# %%
x=d['Low']
y=d['Last']
pt.plot(x,y)

# %%
x=d['Low']
y=d['Close']
pt.plot(x,y)

# %%
x=d['Low']
y=d['VWAP']
pt.plot(x,y)

# %%
x=d['Low']
y=d['Volume']
pt.plot(x,y)

# %%
x=d['Low']
y=d['Turnover']
pt.plot(x,y)

# %%
x=d['Low']
y=d['Trades']
pt.plot(x,y)

# %%
x=d['Low']
y=d['%Deliverble']
pt.plot(x,y)

# %%
x=d['Last']
y=d['Close']
pt.plot(x,y)

# %%
x=d['Last']
y=d['VWAP']
pt.plot(x,y)

# %%
x=d['Last']
y=d['Volume']
pt.plot(x,y)

# %%
x=d['Last']
y=d['Turnover']
pt.plot(x,y)

# %%
x=d['Last']
y=d['Trades']
pt.plot(x,y)

# %%
x=d['Last']
y=d['%Deliverble']
pt.plot(x,y)

# %%
x=d['Close']
y=d['%Deliverble']
pt.plot(x,y)

# %%
x=d['Close']
y=d['VWAP']
pt.plot(x,y)

# %%
x=d['Close']
y=d['Turnover']
pt.plot(x,y)

# %%
x=d['Close']
y=d['Volume']
pt.plot(x,y)

# %%
x=d['Close']
y=d['Trades']
pt.plot(x,y)

# %%
x=d['VWAP']
y=d['%Deliverble']
pt.plot(x,y)

# %%
x=d['VWAP']
y=d['Volume']
pt.plot(x,y)

# %%
x=d['VWAP']
y=d['Turnover']
pt.plot(x,y)

# %%
x=d['VWAP']
y=d['Trades']
pt.plot(x,y)

# %%
x=d['Volume']
y=d['%Deliverble']
pt.plot(x,y)

# %%
x=d['Volume']
y=d['Turnover']
pt.plot(x,y)

# %%
x=d['Volume']
y=d['Trades']
pt.plot(x,y)

# %%
x=d['Turnover']
y=d['%Deliverble']
pt.plot(x,y)

# %%
x=d['Turnover']
y=d['Trades']
pt.plot(x,y)

# %%
x=d['Trades']
y=d['%Deliverble']
pt.plot(x,y)

# %%
corr_matrix=d.corr()
print(corr_matrix)
# Out:
#                     Prev Close      Open      High       Low      Last  \
# Prev Close            1.000000  0.999668  0.998832  0.998699  0.997970
# Open                  0.999668  1.000000  0.999097  0.998986  0.998220
# High                  0.998832  0.999097  1.000000  0.998641  0.999288
# Low                   0.998699  0.998986  0.998641  1.000000  0.999007
# Last                  0.997970  0.998220  0.999288  0.999007  1.000000
# Close                 0.998042  0.998296  0.999320  0.999111  0.999960
# VWAP                  0.998864  0.999130  0.999661  0.999507  0.999621
# Volume                0.458575  0.461223  0.479024  0.449972  0.466777
# Turnover              0.538105  0.540941  0.555747  0.531109  0.544525
# Trades                0.547059  0.549543  0.565272  0.538113  0.552826
# Deliverable Volume    0.152155  0.152540  0.161685  0.145933  0.155418
# %Deliverble          -0.436822 -0.438271 -0.444524 -0.434751 -0.440716
#
# ...

# %%
import seaborn as sn
import matplotlib.pyplot as plt
sn.heatmap(corr_matrix,annot=True)
# Out:
# <Axes: >

# %%
cov_matrix=d.cov()
print(cov_matrix)
# Out:
#                       Prev Close          Open          High           Low  \
# Prev Close          1.429394e+04  1.433777e+04  1.454116e+04  1.407357e+04
# Open                1.433777e+04  1.439129e+04  1.459446e+04  1.412548e+04
# High                1.454116e+04  1.459446e+04  1.482726e+04  1.433290e+04
# Low                 1.407357e+04  1.412548e+04  1.433290e+04  1.389274e+04
# Last                1.429433e+04  1.434650e+04  1.457777e+04  1.410694e+04
# Close               1.430175e+04  1.435401e+04  1.458476e+04  1.411472e+04
# VWAP                1.431897e+04  1.437149e+04  1.459530e+04  1.412569e+04
# Volume              2.483046e+08  2.505876e+08  2.641718e+08  2.402027e+08
# Turnover            1.948510e+16  1.965437e+16  2.049589e+16  1.895996e+16
# Trades              3.346408e+06  3.373027e+06  3.521731e+06  3.245161e+06
# Deliverable Volume  2.622332e+07  2.637893e+07  2.838074e+07  2.479541e+07
# ...

# %%
#@title Default title text
import seaborn as sn
import matplotlib.pyplot as plt
sn.heatmap(cov_matrix,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# LINEAR REGRESSION

# %%
x=d.iloc[:,0:13].values
y=d.iloc[:,13:14].values

# %%
y=d['Deliverable Volume']
print(y)
# Out:
# 0       1004327
# 1        404925
# 2        721545
# 3        861145
# 4        820653
#          ...
# 2294     838079
# 2295    1779639
# 2296    1342353
# 2297    1304895
# 2298    3514692
# Name: Deliverable Volume, Length: 2299, dtype: int64

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
x=d.drop(columns=['Date'])
x=x.drop(columns=['Symbol'])
x=x.drop(columns=['Series'])
print(x)
# Out:
#       Prev Close   Open    High     Low   Last   Close    VWAP    Volume  \
# 0         135.50  137.1  141.00  135.00  140.1  140.00  138.13   1636196
# 1         140.00  142.0  143.80  138.70  143.0  141.70  141.25    890591
# 2         141.70  144.0  150.55  143.15  149.5  149.40  146.72   1456077
# 3         149.40  151.9  157.60  150.25  155.4  155.40  153.76   1634070
# 4         155.40  155.4  155.40  145.10  146.4  146.75  149.54   1657609
# ...          ...    ...     ...     ...    ...     ...     ...       ...
# 2294      725.35  733.0  739.65  728.90  729.2  730.75  733.25   9390549
# 2295      730.75  735.0  757.50  727.35  748.6  749.15  747.67  20573107
# 2296      749.15  755.0  760.00  741.10  743.4  746.25  751.02  11156977
# 2297      746.25  753.2  765.85  743.40  746.4  746.75  753.06  13851910
# 2298      746.75  739.0  759.45  724.50  726.4  730.05  743.35  12600934
#
#           Turnover  Trades  Deliverable Volume  %Deliverble
# ...

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr=LinearRegression()

# %%
mm=lr.fit(x_train,y_train)

# %%
yp=mm.predict(x_test)

# %%
print(yp)
# Out:
# [1.8489020e+06 4.4533200e+05 2.8117400e+05 3.5323720e+06 1.8675030e+06
#  3.9574160e+06 1.1042750e+06 1.2623720e+06 1.5665500e+05 2.0433110e+06
#  1.6671800e+05 8.4643800e+05 2.0558700e+05 4.0626150e+06 4.4012800e+05
#  3.4054400e+05 2.9436860e+06 5.2810720e+06 4.5334400e+05 6.5602100e+05
#  1.2903320e+06 2.2315380e+06 2.4673050e+06 5.7746300e+05 8.6293700e+05
#  2.9094900e+05 3.5770840e+06 3.9895880e+06 4.1079300e+05 2.5852000e+06
#  3.2582720e+06 1.4561360e+06 1.2653230e+06 2.1414520e+06 2.5956050e+06
#  1.3439030e+06 1.6666720e+06 7.6494800e+05 1.8778420e+06 1.7455150e+06
#  6.1626900e+05 2.4111280e+06 6.5902300e+05 8.9364300e+05 1.4165760e+06
#  5.8947400e+05 3.2269540e+06 7.0134700e+05 3.0089000e+05 1.3717480e+06
#  6.9609510e+06 2.4514650e+06 6.6440700e+05 8.8191100e+05 6.8901200e+05
#  4.4903800e+05 1.8771940e+06 2.3419180e+06 2.9798490e+06 7.6475500e+05
#  6.0776400e+05 9.1257200e+05 4.7352300e+05 3.5923910e+06 1.8719320e+06
# ...

# %%
from sklearn.metrics import mean_squared_error
print(mean_squared_error(yp,y_test))
# Out:
# 4.2045290233543665e-18

# %%
from sklearn.metrics import mean_absolute_error
print(mean_absolute_error(yp,y_test))
# Out:
# 1.2994108977221438e-09

# %% [markdown]
# KNN ALGORITHM

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size = 0.25, random_state = 0)

# %%
#normalizing(to transform features to be o a similar scale) the data-standardscaler
# standardscaler it helps converting all numerical values into the one range
from sklearn.preprocessing import StandardScaler
sc_x = StandardScaler()
xtrain = sc_x.fit_transform(xtrain)#normalizing
xtest = sc_x.transform(xtest)

# %%
from sklearn.neighbors import KNeighborsRegressor
knn=KNeighborsRegressor(n_neighbors=20)

# %%
knn.fit(xtrain,ytrain)
# Out:
# KNeighborsRegressor(n_neighbors=20)

# %%
import pandas as pd
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
d=pd.read_csv('/content/drive/MyDrive/AIML/ADANIPORTS CSV FILE ')

# %%
X_train, X_test, y_train, y_test = train_test_split(df.drop('Deliverable Volume', axis=1), 
                                                    df['Deliverable Volume'], 
                                                    test_size=0.2, 
                                                    random_state=42)

# %%
model = KNeighborsRegressor(n_neighbors=5)

# %%
model.fit(x_train, y_train)
# Out:
# KNeighborsRegressor()

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([1859677.8, 1285674.4,  286068.8, 2369144.6, 2214526.8, 2906129.8,
#        1240971.8, 1118437.6,  135078.6, 1847489.8,  210271. , 1050130.4,
#         218051.2, 3399072. ,  732586.2,  188234.6, 2436198.8, 4403992.4,
#         970590.4, 1001113.2, 1190189.4, 1695617.6, 2778835.6, 1954462.2,
#        2958873.4,  269236.2, 1646806.8, 2159960.4,  209845.8, 2401685.8,
#        4396811.4,  784266.8,  930047.4, 2958873.4, 2695332.4, 1821257.8,
#        2247195.2,  795386. , 1451538. , 1095874.6,  987892. , 1573801. ,
#         644251.4,  909432.8, 1198799. ,  575188.4, 1916413.6,  990294.6,
#         292169.6, 1155703.4, 2678754.4, 2988944.2,  906807.4,  766276.2,
#        1025912.8, 1134890.8, 3381021.8, 2525673.6, 2621356.2,  871728.6,
#         705912. ,  573090.6,  599935. , 2881885.2, 1344513. ,  534453.4,
#        1057697. ,  575803.2, 1383238.4, 1661603.4, 1438116.2, 1455771.4,
#        1056605.6, 1530370.2, 1194401. , 1593618.6, 1150312.6, 3744212.2,
# ...

# %%
from sklearn.metrics import mean_squared_error
print(mean_squared_error(yp,y_test))
# Out:
# 4.2045290233543665e-18

# %%
from sklearn.metrics import mean_absolute_error
print(mean_absolute_error(yp,y_test))
# Out:
# 1.2994108977221438e-09

# %% [markdown]
# DECISION TREE

# %%
from sklearn.tree import DecisionTreeRegressor
dtc=DecisionTreeRegressor()

# %%
dtc.fit(xtrain,ytrain)
# Out:
# DecisionTreeRegressor()

# %%
y_pred=dtc.predict(xtest)
y_pred
# Out:
# array([1848265.,  447618.,  281038., 3532683., 1871391., 3957607.,
#        1101595., 1264807.,  136245., 2042773.,  165720.,  847542.,
#         208041., 4101433.,  440203.,  340906., 2947365., 5242192.,
#         454883.,  655214., 1288295., 2235636., 2475361.,  576929.,
#         861907.,  293733., 3586471., 3957607.,  410306., 2593908.,
#        3289721., 1455253., 1264807., 2141672., 2593908., 1340274.,
#        1686272.,  767128., 1877028., 1739613.,  614296., 2409180.,
#         658885.,  893291., 1417246.,  592311., 3226495.,  700161.,
#         299197., 1371313., 7099348., 2454793.,  660950.,  882422.,
#         691543.,  449757., 1876225., 2334929., 2978829.,  764635.,
#         606368.,  917840.,  473286., 3586471., 1870738.,  349389.,
#        1016029.,  841282., 1830147., 3331147.,  525027., 1465404.,
#        1283807., 1666342.,  767128., 4653276., 1052373., 2561470.,
#        3845527., 2501201.,  554928., 1449223.,  976196.,  745258.,
# ...

# %%
from sklearn.metrics import mean_squared_error
print(mean_squared_error(yp,y_test))
# Out:
# 4.2045290233543665e-18

# %%
from sklearn.metrics import mean_absolute_error
print(mean_absolute_error(yp,y_test))
# Out:
# 1.2994108977221438e-09

# %% [markdown]
# SUPPORT VECTOR MACHINE

# %%
from sklearn import svm
SVM= svm.SVR()

# %%
SVM.fit(xtrain, ytrain)
# Out:
# SVR()

# %%
print("Training Accuracy",SVM.score(xtrain,ytrain))
print("Testing Accuracy",SVM.score(xtest,ytest))
print("Overall Accuracy:",SVM.score(sc_x.transform(x),y))
# Out:
# Training Accuracy 1.0
# Testing Accuracy 0.0
# Overall Accuracy: 0.7498912570682905

# %%
y_pred=SVM.predict(xtest)
y_pred
# Out:
# array([1149094.41074491, 1148948.548278  , 1148870.0909268 ,
#        1149221.09762712, 1149088.18964584, 1149210.11167548,
#        1149009.09914568, 1149086.85630013, 1148868.00583093,
#        1149158.60327021, 1148868.96156191, 1148949.81573475,
#        1148873.63111538, 1149234.57147363, 1148954.5534173 ,
#        1148906.57745449, 1149189.45962113, 1149090.94880601,
#        1148962.03244702, 1148947.83196114, 1149090.76853406,
#        1149122.53148303, 1149161.36041858, 1148940.63352937,
#        1149001.02981678, 1148878.19515261, 1149226.33539773,
#        1149146.40963015, 1148914.93665144, 1149171.39337203,
#        1149201.3009608 , 1149006.85904568, 1149054.58344865,
#        1149102.02981949, 1149178.80746396, 1149028.61760917,
#        1149081.73632609, 1148966.5899245 , 1149130.8825375 ,
#        1149025.08688512, 1148888.58735713, 1149159.65105713,
#        1149029.03542073, 1148917.73413976, 1149027.83906848,
# ...

# %%
from sklearn.metrics import mean_squared_error
print(mean_squared_error(yp,y_test))
# Out:
# 4.2045290233543665e-18

# %%
from sklearn.metrics import mean_absolute_error
print(mean_absolute_error(yp,y_test))
# Out:
# 1.2994108977221438e-09
